# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')
df.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
df.shape
# Out:
# (129971, 14)

# %%
df.dtypes 
# float64 acumula mais valor na memoria
# category o Pithon compreende e nomeia assim
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df.describe() # descrição estatisticas em dados numéricos
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Length: 129971, dtype: bool

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
del df['Unnamed: 0']

# %%
del df['taster_twitter_handle']

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
df.head(100)
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         US  Much like the regular bottling from 2012, this...
# ..       ...                                                ...
# 95    France  This is a dense wine, packed with both tannins...
# 96    France  The wine comes from one of the cru estates fol...
# 97        US  A wisp of bramble extends a savory tone from n...
# 98     Italy  Forest floor, menthol, espresso, cranberry and...
# 99        US  This blends 20% each of all five red-Bordeaux ...
#
#                            designation  points  price           province  \
# 0                         Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
df.dropna(inplace = True)

# %%
#del df['taster_name']

# %%
df.isnull().sum()
# Out:
# country        0
# description    0
# designation    0
# points         0
# price          0
# province       0
# region_1       0
# region_2       0
# taster_name    0
# title          0
# variety        0
# winery         0
# dtype: int64

# %%
df.designation.fillna('no information', inplace = True)

# %%
df.region_1.fillna('no information', inplace = True)

# %%
df.region_2.fillna('no information', inplace = True)

# %%
df.variety.fillna('no information', inplace = True)

# %%
df.price.fillna(0, inplace = True)

# %%
df.country.fillna('no information', inplace = True)

# %%
df.head(100)
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         US  Tart and snappy, the flavors of lime flesh and...
# 3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         US  Much like the regular bottling from 2012, this...
# ..       ...                                                ...
# 95    France  This is a dense wine, packed with both tannins...
# 96    France  The wine comes from one of the cru estates fol...
# 97        US  A wisp of bramble extends a savory tone from n...
# 98     Italy  Forest floor, menthol, espresso, cranberry and...
# 99        US  This blends 20% each of all five red-Bordeaux ...
#
#                            designation  points  price           province  \
# 0                         Vulkà Bianco      87    0.0  Sicily & Sardinia
# ...

# %%
df
# Out:
#        country                                        description  \
# 4           US  Much like the regular bottling from 2012, this...
# 10          US  Soft, supple plum envelopes an oaky structure ...
# 23          US  This wine from the Geneseo district offers aro...
# 25          US  Oak and earth intermingle around robust aromas...
# 35          US  As with many of the Erath 2010 vineyard design...
# ...        ...                                                ...
# 129919      US  This ripe, rich, almost decadently thick wine ...
# 129926      US  This pure Syrah from Reininger's estate vineya...
# 129945      US  Hailing from one of the more popular vineyards...
# 129949      US  There's no bones about the use of oak in this ...
# 129950      US  This opens with herbaceous dollops of thyme an...
#
#                                designation  points  price    province  \
# 4       Vintner's Reserve Wild Child Block      87   65.0      Oregon
# ...

# %%
df5 = df.set_index('country').sort_values(by='points', ascending = False)

# %%
df5.dropna()
# Out:
#                                                  description  \
# country
# Portugal   A powerful and ripe wine, strongly influenced ...
# France     This new release from a great vintage for Char...
# US         In 2005 Charles Smith introduced three high-en...
# Italy      This gorgeous, fragrant wine opens with classi...
# US         Initially a rather subdued Frog; as if it has ...
# ...                                                      ...
# Argentina  Severely compromised by green, minty, weedy ar...
# Argentina  Disappointing considering the source. The nose...
# Peru       Best on the nose, where apple and lemony aroma...
# Chile      There's not much point in making a reserve-sty...
# US         A hot, harsh and unbalance Chardonnay. Barely ...
#
#                               designation  points  price          province  \
# country
# Portugal                 Nacional Vintage     100  650.0              Port
# ...

# %%
a = df5.loc['Brazil']
a.set_index(['winery','variety'])
# Out:
#                                                                                   description  \
# winery           variety
# Cave Geisse      Sparkling Blend            Stony polished white-fruit aromas are lean and...
#                  Chardonnay                 Dusty white-fruit aromas are mild and slightly...
# Casa Valduga     Champagne Blend            Briny stone-fruit aromas are sweetened by note...
# Lidio Carraro    Merlot                     Cherry, plum and earth aromas form a sound bou...
# Casa Perini      Moscatel                   Attractive aromas of gardenia, lemon-lime soda...
# Lidio Carraro    Chardonnay                 Initial aromas of vanilla wafer give way to pe...
# Cave Geisse      Sparkling Blend            Pear, apple and wet-stone aromas are tight, wh...
# Casa Perini      Sparkling Blend            Peach pit and citrus-rind aromas are solid, fo...
# Cave Geisse      Pinot Noir                 Mild citrus aromas are aided by crushed minera...
# ...

# %%
del a['region_1']

# %%
del a['region_2']

# %%
a.count()
# Out:
# description    52
# designation    52
# points         52
# price          52
# province       52
# title          52
# variety        52
# winery         52
# dtype: int64

# %%
a.set_index(['winery','variety']).sort_values(by = 'points', ascending = False)
# Out:
#                                                                                   description  \
# winery           variety
# Cave Geisse      Sparkling Blend            Stony polished white-fruit aromas are lean and...
#                  Chardonnay                 Dusty white-fruit aromas are mild and slightly...
# Casa Valduga     Champagne Blend            Briny stone-fruit aromas are sweetened by note...
# Casa Perini      Moscatel                   Attractive aromas of gardenia, lemon-lime soda...
# Lidio Carraro    Chardonnay                 Initial aromas of vanilla wafer give way to pe...
# Cave Geisse      Sparkling Blend            Pear, apple and wet-stone aromas are tight, wh...
# Lidio Carraro    Merlot                     Cherry, plum and earth aromas form a sound bou...
# Casa Perini      Sparkling Blend            Peach pit and citrus-rind aromas are solid, fo...
# Cave Geisse      Pinot Noir                 Mild citrus aromas are aided by crushed minera...
# ...

# %%
# Out:
#                                                description  \
# country
# Brazil   Stony polished white-fruit aromas are lean and...
# Brazil   Dusty white-fruit aromas are mild and slightly...
# Brazil   Briny stone-fruit aromas are sweetened by note...
# Brazil   Cherry, plum and earth aromas form a sound bou...
# Brazil   Attractive aromas of gardenia, lemon-lime soda...
#
#                   designation  points  price        province  \
# country
# Brazil            Brut Nature      89   36.0  Pinto Bandeira
# Brazil   Blanc de Blancs Brut      89   45.0  Pinto Bandeira
# Brazil               130 Brut      88   33.0          Brazil
# Brazil                  Agnus      88   15.0    Serra Gaúcha
# Brazil         no information      88   20.0   Vale Trentino
#
#                                                      title          variety  \
# country
# Brazil   Cave Geisse 2013 Brut Nature Sparkling (Pinto ...  Sparkling Blend
# ...

# %%
df1.isnull().sum()
# Out:
# country        0
# description    0
# designation    0
# points         0
# price          0
# province       0
# region_1       0
# region_2       0
# taster_name    0
# title          0
# variety        0
# winery         0
# dtype: int64

# %%
df1.count()
# Out:
# country        1000
# description    1000
# designation    1000
# points         1000
# price          1000
# province       1000
# region_1       1000
# region_2       1000
# taster_name    1000
# title          1000
# variety        1000
# winery         1000
# dtype: int64

# %%
db = firebase.database()

# %%
from time import time 
import numpy as np
x = int(time()) 
df1['id'] = np.arange(x, x + 1000)

# %%
df1.columns
# Out:
# Index(['id', 'country', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name', 'title', 'variety',
#        'winery'],
#       dtype='object')

# %%
df1['id'].astype
# Out:
# <bound method NDFrame.astype of 4       1583095746
# 10      1583095747
# 23      1583095748
# 25      1583095749
# 35      1583095750
#            ...
# 5272    1583096741
# 5275    1583096742
# 5280    1583096743
# 5283    1583096744
# 5287    1583096745
# Name: id, Length: 1000, dtype: int32>

# %%
df1.loc['country'] = 'Brazil'

# %% [markdown]
# # DATABASE FIREBASE

# %%
import pyrebase
import pandas as pd
from time import time



con = {
    'apiKey': "AIzaSyBANvozfZCLvwATKh3mRGjAVTvftVTMK-Q",
    'authDomain': "wine-reviews-f7355.firebaseapp.com",
    'databaseURL': "https://wine-reviews-f7355.firebaseio.com",
    'projectId': "wine-reviews-f7355",
    'storageBucket': "wine-reviews-f7355.appspot.com",
    'messagingSenderId': "635062978338",
    'appId': "1:635062978338:web:b4d834c3b8e50d08ff477b",
    'measurementId': "G-2RLGW5W61J"
  }


firebase = pyrebase.initialize_app(con)
db = firebase.database()
storage = firebase.storage()

# %%
# def database(df1):
#     for x in df1.values:
#         base = {'id': x[0],
#                 "country": x[1],
#                 "description": x[2],
#                 "designation": x[3],
#                 "points": x[4],
#                 "price": x[5],
#                 "province": x[6],
#                 "region_1": x[7],
#                 "region_2": x[8],
#                 "taster_name": x[9],
#                 "title": x[10],
#                 "variety": x[11],
#                 "winery": x[12]
#                }
        
#         db.child("Top_wines").child(x[0]).set(base)
        
# database(df1)

# %% [markdown]
# # 5. Indexar coluna id, points e province;

# %% [raw]
# {
#   "rules": {
#     "Top_wines":{
#       ".indexOn": ["id","points","province"]
#     },
#     ".read": true,
#     ".write": true
#   }
# }

# %% [markdown]
# # 6. Criar função que adicione um novo dado com a chave sendo o timestamp e salve uma imagem no storage em que o nome da imagem seja o timestamp numa pasta imagens;

# %%
def vinho(data,imagem):
    id = int(time())
    print(id)
    db.child('Top_wines').child(id).set(data)
    storage.child('images/{}.png'.format(id)).put(imagem)




wines ={'id': int(time()),
      'country': 'BRAZIL',
      'description': "Much like the regular bottling from 2012, ...", 
      'designation': "Vintner's Reserve Wild Child Block", 
      'points': 87, 
      'price': 65.0, 
      'province': 'Oregon', 
      'region_1': 'Willamette Valley', 
      'region_2': 'Willamette Valley', 
      'taster_name': 'Paul Gregutt', 
      'title': "Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)", 
      'variety': 'Pinot Noir', 
      'winery': 'Sweet Cheeks'}

vinho(wines, 'c:/perini.png')
# Out:
# 1583098646

# %% [raw]
# wine-reviews-f7355 Top_wines 1583098646
# 1583098646
# country:
# "BRAZIL"
# description:
# "Much like the regular bottling from 2012, ..."
# designation:
# "Vintner's Reserve Wild Child Block"
# id:
# 1583098646
# points:
# 87
# price:
# 65
# province:
# "Oregon"
# region_1:
# "Willamette Valley"
# region_2:
# "Willamette Valley"
# taster_name:
# "Paul Gregutt"
# title:
# "Sweet Cheeks 2012 Vintner's Reserve Wild Child ..."
# variety:
# "Pinot Noir"
# winery:
# "Sweet Cheeks"

# %% [markdown]
# # 7. Criar função que retorne os 15 primeiros dados em ordem crescente de points;

# %%
def tops_wines():
    tops = db.child('Top_wines').order_by_child('points').limit_to_first(15).get()
    print(tops.val())
    
tops_wines()
# Out:
# OrderedDict([('1583096603', {'country': 'US', 'description': "Earthy and very tight after aging 20 months in barrel and another two years in bottle prior to release, this wine's fruit is slipping away, leaving behind only a pruney sourness.", 'designation': 'Westside Vineyard', 'id': 1583096603, 'points': 81, 'price': 25.0, 'province': 'California', 'region_1': 'Amador County', 'region_2': 'Sierra Foothills', 'taster_name': 'Virginie Boone', 'title': 'Amador Cellars 2006 Westside Vineyard Zinfandel (Amador County)', 'variety': 'Zinfandel', 'winery': 'Amador Cellars'}), ('1583095799', {'country': 'US', 'description': 'Plummy and hinting at black cherry, this wine is otherwise soft and simple, with a distracting, full-throttled descent into raisin cake and prune.', 'designation': 'Serracino Reserve', 'id': 1583095799, 'points': 82, 'price': 48.0, 'province': 'California', 'region_1': 'Dry Creek Valley', 'region_2': 'Sonoma', 'taster_name': 'Virginie Boone', 'title': 'Pezzi King 2013 Se
# ...

# %% [markdown]
# # 8. Criar função que retorne todos os dados pelo nome da province;

# %%
def province(provin):
    provincia = db.child('Top_wines').order_by_child('province').equal_to(provin).get()
    print(provincia.val())
        
province('Oregon')
# Out:
# OrderedDict([('1583095937', {'country': 'US', 'description': "This is smooth and accessible, putting a light chocolate frame around rhubarb and strawberry fruit. There's a hint of pepper, and the wine is fresh and youthful, good sipping wine for late summer/early fall.", 'designation': 'Atração', 'id': 1583095937, 'points': 87, 'price': 25.0, 'province': 'Oregon', 'region_1': 'Willamette Valley', 'region_2': 'Willamette Valley', 'taster_name': 'Paul Gregutt', 'title': 'Coelho 2014 Atração Pinot Noir (Willamette Valley)', 'variety': 'Pinot Noir', 'winery': 'Coelho'}), ('1583095821', {'country': 'US', 'description': 'Dense, dark and spicy, this opens with a thicket of briar and bramble—one almost wants to say thistle—wrapped around taut, compact black fruits. There is a hint of gun metal running through the palate, and as the wine warms and slowly opens, it reveals a lingering finish with a little pat of butter left on the tongue. This should be in fine shape for at least another decad
# ...

# %% [markdown]
# # Criar função que remove nó pelo timestamp;

# %%
def remove(id):
    db.child('Top_wines').child(id).remove()
    
remove(1583095821)

# %% [markdown]
# # 10. Criar função que atualiza nó pelo timestamp;

# %%
def update(id, data):
    db.child('Top_wines').child(id).update(data)

wines ={'id': 1583095966,
      'country': 'BRAZIL',
      'description': "Much like the regular bottling from 2012, ...", 
      'designation': "Vintner's Reserve Wild Child Block", 
      'points': 87, 
      'price': 65.0, 
      'province': 'Oregon', 
      'region_1': 'Willamette Valley', 
      'region_2': 'Willamette Valley', 
      'taster_name': 'Paul Gregutt', 
      'title': "Sweet Cheeks 2012 Vintner's Reserve Wild Child Block Pinot Noir (Willamette Valley)", 
      'variety': 'Pinot Noir', 
      'winery': 'Sweet Cheeks'}

update(1583095966,wines)
